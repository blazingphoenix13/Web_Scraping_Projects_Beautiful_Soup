# %%
import requests
from bs4 import BeautifulSoup

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

# %% [markdown]
# #### Scraping smartphones with discount on Amazon

# %%
url ="https://www.amazon.in/s?k=smartphones+with+discount&ref=nb_sb_noss_2"
response = requests.get(url)

# %%
print(response.content[:400])
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]> <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->\n<!--[if IE 7]>    <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->\n<!--[if IE 8]>    <html lang="en-us" class="a-no-js a-lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!-->\n<html class="a-no-js" lang="en-us"><!--<![endif]--><head>\n<meta http-equiv="content-type" content="text/ht'

# %%
response = requests.get(url, headers=headers)
print(response.text)
# Out:
# <!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <script type='text/javascript'>var ue_t0=ue_t0||+new Date();</script><!-- sp:feature:cs-optimization -->
# <meta http-equiv='x-dns-prefetch-control' content='on'><link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com"><link rel="dns-prefetch" href="https://m.media-amazon.com"><link rel="dns-prefetch" href="https://completion.amazon.com"><script type='text/javascript'>
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
soup = BeautifulSoup(response.content, features="lxml")

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">\n <!-- sp:feature:head-start -->\n <head>\n  <script>\n   var aPageStart = (new Date()).getTime();\n  </script>\n  <meta charset="utf-8"/>\n  <script type="text/javascript">\n   var ue_t0=ue_t0||+new Date();\n  </script>\n  <!-- sp:feature:cs-optimization -->\n  <meta content="on" http-equiv="x-dns-prefetch-control"/>\n  <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>\n  <link href="https://m.media-amazon.com" rel="dns-prefetch"/>\n  <link href="https://completion.amazon.com" rel="dns-prefetch"/>\n  <script type="text/javascript">\n   window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_i
# ...

# %% [markdown]
# #### Extract all titles

# %%
# Method - 1
r1 = soup.find('span', class_="a-size-medium")
print(r1)
print('----------')
r2 = soup.find('span', class_="a-size-medium")
print(r2.text)
# Out:
# <span class="a-size-medium a-color-base a-text-normal">Redmi 7A (Matte Blue, 2GB RAM, 32GB Storage)</span>
# ----------
# Redmi 7A (Matte Blue, 2GB RAM, 32GB Storage)

# %%
# Method - 2
r1 = soup.find('span', attrs={"a-size-medium"})
print(r1)
print('----------')
r2 = soup.find('span', attrs={"a-size-medium"})
print(r2.text)
# Out:
# <span class="a-size-medium a-color-base a-text-normal">Redmi 7A (Matte Blue, 2GB RAM, 32GB Storage)</span>
# ----------
# Redmi 7A (Matte Blue, 2GB RAM, 32GB Storage)

# %%
for i in soup.find_all('span', class_="a-size-medium"):
    print(i)
# Out:
# <span class="a-size-medium a-color-base a-text-normal">Redmi 7A (Matte Blue, 2GB RAM, 32GB Storage)</span>
# <span class="a-size-medium a-color-base a-text-normal">Vivo U10 (Thunder Black, 5000 mAH 18W Fast Charge Battery, 4GB RAM, 64GB Storage)</span>
# <span class="a-size-medium a-color-base a-text-normal">Redmi 7A (Matte Black, 2GB RAM, 16GB Storage)</span>
# <span class="a-size-medium a-color-base a-text-normal">10.or Crafted for Amazon G2 (Twilight Blue, 4GB RAM, 64GB Storage)</span>
# <span class="a-size-medium a-color-base a-text-normal">Redmi 7A (Matte Blue, 2GB RAM, 16GB Storage)</span>
# <span class="a-size-medium a-color-base a-text-normal">OPPO A7 (Glaring Gold, 3GB RAM, 64GB Storage)</span>
# <span class="a-size-medium a-color-base a-text-normal">Nokia 4.2 (Black, 3GB RAM, 32GB Storage)</span>
# <span class="a-size-medium a-color-base a-text-normal">Redmi Y3 (Prime Black, 3GB RAM, 32MP Selfie Camera, 32GB Storage, 4000mAH Battery)</span>
# ...

# %%
for i in soup.find_all('span', class_="a-size-medium"):
    print(i.text)
# Out:
# Redmi 7A (Matte Blue, 2GB RAM, 32GB Storage)
# Vivo U10 (Thunder Black, 5000 mAH 18W Fast Charge Battery, 4GB RAM, 64GB Storage)
# Redmi 7A (Matte Black, 2GB RAM, 16GB Storage)
# 10.or Crafted for Amazon G2 (Twilight Blue, 4GB RAM, 64GB Storage)
# Redmi 7A (Matte Blue, 2GB RAM, 16GB Storage)
# OPPO A7 (Glaring Gold, 3GB RAM, 64GB Storage)
# Nokia 4.2 (Black, 3GB RAM, 32GB Storage)
# Redmi Y3 (Prime Black, 3GB RAM, 32MP Selfie Camera, 32GB Storage, 4000mAH Battery)
# Apple iPhone 11 (64GB) - White
# OPPO F11 (Marble Green, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers
# Redmi Note 8 Pro (Electric Blue, 6GB RAM, 128GB Storage with Helio G90T Processor) - Upto 6 Months No Cost EMI
# OPPO A9 (Marble Green, 4GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers
# Apple iPhone XR (128GB) - Black
# Apple iPhone XR (64GB) - White
# SanDisk 64GB Class 10 microSDXC Memory Card with Adapter (SDSQUAR-064G-GN6MA)
# ...

# %%
detail =[]
for i in soup.find_all('span', class_="a-size-medium"):
    detail.append(i.text)
print(detail)
# Out:
# ['Redmi 7A (Matte Blue, 2GB RAM, 32GB Storage)', 'Vivo U10 (Thunder Black, 5000 mAH 18W Fast Charge Battery, 4GB RAM, 64GB Storage)', 'Redmi 7A (Matte Black, 2GB RAM, 16GB Storage)', '10.or Crafted for Amazon G2 (Twilight Blue, 4GB RAM, 64GB Storage)', 'Redmi 7A (Matte Blue, 2GB RAM, 16GB Storage)', 'OPPO A7 (Glaring Gold, 3GB RAM, 64GB Storage)', 'Nokia 4.2 (Black, 3GB RAM, 32GB Storage)', 'Redmi Y3 (Prime Black, 3GB RAM, 32MP Selfie Camera, 32GB Storage, 4000mAH Battery)', 'Apple iPhone 11 (64GB) - White', 'OPPO F11 (Marble Green, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers', 'Redmi Note 8 Pro (Electric Blue, 6GB RAM, 128GB Storage with Helio G90T Processor) - Upto 6 Months No Cost EMI', 'OPPO A9 (Marble Green, 4GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers', 'Apple iPhone XR (128GB) - Black', 'Apple iPhone XR (64GB) - White', 'SanDisk 64GB Class 10 microSDXC Memory Card with Adapter (SDSQUAR-064G-GN6MA)', 'Samsung EVO Plus 32GB microSDH
# ...

# %%
name = [i.split(' (')[0] for i in detail]
print(name)
print(len(name))
# Out:
# ['Redmi 7A', 'Vivo U10', 'Redmi 7A', '10.or Crafted for Amazon G2', 'Redmi 7A', 'OPPO A7', 'Nokia 4.2', 'Redmi Y3', 'Apple iPhone 11', 'OPPO F11', 'Redmi Note 8 Pro', 'OPPO A9', 'Apple iPhone XR', 'Apple iPhone XR', 'SanDisk 64GB Class 10 microSDXC Memory Card with Adapter', 'Samsung EVO Plus 32GB microSDHC UHS-I U1 95MB/s Full HD Memory Card with Adapter']
# 16

# %%
desc = [i.split(' (')[1] for i in detail]
print(desc)
# Out:
# ['Matte Blue, 2GB RAM, 32GB Storage)', 'Thunder Black, 5000 mAH 18W Fast Charge Battery, 4GB RAM, 64GB Storage)', 'Matte Black, 2GB RAM, 16GB Storage)', 'Twilight Blue, 4GB RAM, 64GB Storage)', 'Matte Blue, 2GB RAM, 16GB Storage)', 'Glaring Gold, 3GB RAM, 64GB Storage)', 'Black, 3GB RAM, 32GB Storage)', 'Prime Black, 3GB RAM, 32MP Selfie Camera, 32GB Storage, 4000mAH Battery)', '64GB) - White', 'Marble Green, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers', 'Electric Blue, 6GB RAM, 128GB Storage with Helio G90T Processor) - Upto 6 Months No Cost EMI', 'Marble Green, 4GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers', '128GB) - Black', '64GB) - White', 'SDSQUAR-064G-GN6MA)', 'MB-MC32GA)']

# %%
desc = [i.replace(')','') for i in desc]
print(desc)
# Out:
# ['Matte Blue, 2GB RAM, 32GB Storage', 'Thunder Black, 5000 mAH 18W Fast Charge Battery, 4GB RAM, 64GB Storage', 'Matte Black, 2GB RAM, 16GB Storage', 'Twilight Blue, 4GB RAM, 64GB Storage', 'Matte Blue, 2GB RAM, 16GB Storage', 'Glaring Gold, 3GB RAM, 64GB Storage', 'Black, 3GB RAM, 32GB Storage', 'Prime Black, 3GB RAM, 32MP Selfie Camera, 32GB Storage, 4000mAH Battery', '64GB - White', 'Marble Green, 6GB RAM, 128GB Storage with No Cost EMI/Additional Exchange Offers', 'Electric Blue, 6GB RAM, 128GB Storage with Helio G90T Processor - Upto 6 Months No Cost EMI', 'Marble Green, 4GB RAM, 128GB Storage with No Cost EMI/Additional Exchange Offers', '128GB - Black', '64GB - White', 'SDSQUAR-064G-GN6MA', 'MB-MC32GA']

# %%
len(desc)
# Out:
# 16

# %%
name =[]
for i in soup.find_all('span', attrs={"a-size-medium"}):
    name.append(i.text)
print(name)
# Out:
# ['Redmi 7A (Matte Blue, 2GB RAM, 32GB Storage)', 'Vivo U10 (Thunder Black, 5000 mAH 18W Fast Charge Battery, 4GB RAM, 64GB Storage)', 'Redmi 7A (Matte Black, 2GB RAM, 16GB Storage)', '10.or Crafted for Amazon G2 (Twilight Blue, 4GB RAM, 64GB Storage)', 'Redmi 7A (Matte Blue, 2GB RAM, 16GB Storage)', 'OPPO A7 (Glaring Gold, 3GB RAM, 64GB Storage)', 'Nokia 4.2 (Black, 3GB RAM, 32GB Storage)', 'Redmi Y3 (Prime Black, 3GB RAM, 32MP Selfie Camera, 32GB Storage, 4000mAH Battery)', 'Apple iPhone 11 (64GB) - White', 'OPPO F11 (Marble Green, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers', 'Redmi Note 8 Pro (Electric Blue, 6GB RAM, 128GB Storage with Helio G90T Processor) - Upto 6 Months No Cost EMI', 'OPPO A9 (Marble Green, 4GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers', 'Apple iPhone XR (128GB) - Black', 'Apple iPhone XR (64GB) - White', 'SanDisk 64GB Class 10 microSDXC Memory Card with Adapter (SDSQUAR-064G-GN6MA)', 'Samsung EVO Plus 32GB microSDH
# ...

# %% [markdown]
# #### Extract all Discounted Price

# %%
r3 = soup.find('span', class_="a-price-whole")
print(r3)
print('----------')
r4 = soup.find('span', class_="a-price-whole")
print(r4.text)
# Out:
# <span class="a-price-whole">5,499</span>
# ----------
# 5,499

# %%
dis_price=[]
for i in soup.find_all('span', class_="a-price-whole"):
    dis_price.append(i.text)
print(org_price)
# Out:
# ['5,499', '10,990', '4,999', '7,999', '4,999', '12,990', '6,718', '7,999', '64,900', '13,990', '15,999', '11,990', '49,900', '47,900', '739', '419']

# %% [markdown]
# #### Removal of commas from price

# %%
dis_price1 = [i.replace(',','') for i in dis_price]
dis_price1
# Out:
# ['5499',
#  '10990',
#  '4999',
#  '7999',
#  '4999',
#  '12990',
#  '6718',
#  '7999',
#  '64900',
#  '13990',
#  '15999',
#  '11990',
#  '49900',
#  '47900',
#  '739',
#  '419']

# %%
len(dis_price1)
# Out:
# 16

# %% [markdown]
# #### Extract no of Reviews per smartphone

# %%
r5 = soup.find('span', class_="a-size_base")
print(r5)
print('----------')
r6 = soup.find('span', attrs={"a-size_base"})
print(r6)
# Out:
# None
# ----------
# None

# %% [markdown]
# ### Extract get_it_by_date

# %%
r7 = soup.find('span', class_="a-text-bold")
print(r7)
print('----------')
r8 = soup.find('span', attrs={"a-text-bold"})
print(r8.text)
# Out:
# <span class="a-color-state a-text-bold">"smartphones with discount"</span>
# ----------
# "smartphones with discount"

# %%
for i in soup.find_all('span', attrs={"a-text-bold"}):
    print(i.text)
# Out:
# "smartphones with discount"
# Amazon Prime
# Delivery Day
# Prime Now Stores
# Department
# Avg. Customer Review
# Brand
# Pay On Delivery
# Mobile Phone Operating System
# Primary Camera Resolution
# Screen Size
# Device Features
# Data Transfer
# Battery Capacity
# Hifi & Audio Connectivity
# Colour
# Sunday, February 9
# Today, February 7
# Sunday, February 9
# Wednesday, February 12
# Friday, February 14
# Today, February 7
# Today, February 7
# Today, February 7
# Today, February 7
# Today, February 7
# Today, February 7
# Sunday, February 9
# Today, February 7
# Sunday, February 9
# Today, February 7

# %%
delvr_by=[]
for i in soup.find_all('span', attrs={"a-text-bold"}):
    delvr_by.append(i.text)
print(delvr_by)
# Out:
# ['"smartphones with discount"', 'Amazon Prime', 'Delivery Day', 'Prime Now Stores', 'Department', 'Avg. Customer Review', 'Brand', 'Pay On Delivery', 'Mobile Phone Operating System', 'Primary Camera Resolution', 'Screen Size', 'Device Features', 'Data Transfer', 'Battery Capacity', 'Hifi & Audio Connectivity', 'Colour', 'Sunday, February 9', 'Today, February 7', 'Sunday, February 9', 'Wednesday, February 12', 'Friday, February 14', 'Today, February 7', 'Today, February 7', 'Today, February 7', 'Today, February 7', 'Today, February 7', 'Today, February 7', 'Sunday, February 9', 'Today, February 7', 'Sunday, February 9', 'Today, February 7']

# %%
for i in range(len(delvr_by)):
    if delvr_by[i].startswith('Sunday'):
        print(i)
# Out:
# 16
# 18
# 27
# 29

# %%
date_delvr = delvr_by[16:]
date_delvr
# Out:
# ['Sunday, February 9',
#  'Today, February 7',
#  'Sunday, February 9',
#  'Wednesday, February 12',
#  'Friday, February 14',
#  'Today, February 7',
#  'Today, February 7',
#  'Today, February 7',
#  'Today, February 7',
#  'Today, February 7',
#  'Today, February 7',
#  'Sunday, February 9',
#  'Today, February 7',
#  'Sunday, February 9',
#  'Today, February 7']

# %%
print(len(date_delvr))
# Out:
# 15

# %% [markdown]
# #### Converting Product Name, Discounted Price and Date_of_delivery into Excel/Csv file

# %%
import pandas as pd

# %%
df = pd.DataFrame({"Product_Name":name,'Discounted_price':dis_price1,'Description':desc})
df.index =list(range(16))
df
# Out:
#                                          Product_Name Discounted_price  \
# 0                                            Redmi 7A             5499
# 1                                            Vivo U10            10990
# 2                                            Redmi 7A             4999
# 3                         10.or Crafted for Amazon G2             7999
# 4                                            Redmi 7A             4999
# 5                                             OPPO A7            12990
# 6                                           Nokia 4.2             6718
# 7                                            Redmi Y3             7999
# 8                                     Apple iPhone 11            64900
# 9                                            OPPO F11            13990
# 10                                   Redmi Note 8 Pro            15999
# 11                                            OPPO A9            11990
# ...

# %%
df.to_excel('Mobile_Price_comparison.xlsx')

# %%
df.to_csv('Mobile_Price_comparison.csv')

# %% [markdown]
# #### Extract all Saving

# %%
r4 = soup.find('span', attrs={"a-letter-space"})
print(r4)
print('----------')
r5 = soup.find('span', class_="a-letter-space")
print(r5.next_element)
print(r5.next_element.text)
# Out:
# <span class="a-letter-space"></span>
# ----------
# <span>Save ₹1,500 (21%)</span>
# Save ₹1,500 (21%)

# %%
# r5 = soup.find_all('span')
# print(r5)

# %%
# save_str=[]
for i in soup.find_all('span', class_="a-letter-space"):
    print(i.next_element)
# print(save_str)
# Out:
# <span>Save ₹1,500 (21%)</span>
#
#
# <span>Save ₹3,000 (21%)</span>
# <div class="a-row a-size-base a-color-secondary"><div class="a-row">
# <span class="rush-component" data-component-props='{"asin":"B07DJ8K2ZZ"}' data-component-type="s-coupon-component">
# <span class="s-coupon-clipped aok-hidden">
# <span class="a-color-base">₹1,500 coupon applied.</span>
# </span>
# <span class="s-coupon-unclipped">
# <span class="a-size-base s-coupon-highlight-color s-highlighted-text-padding aok-inline-block">
#     Save ₹1,500
# </span>
# <span class="a-color-base"> with coupon</span>
# </span>
# </span>
# </div></div>
# <span>Save ₹1,500 (23%)</span>
#
#
# <span>Save ₹7,000 (47%)</span>
#
#
# <span>Save ₹1,500 (23%)</span>
#
#
# <span>Save ₹4,000 (24%)</span>
#
#
# <span>Save ₹6,281 (48%)</span>
#
#
# <span>Save ₹4,000 (33%)</span>
#
#
#
#
# <span>Save ₹10,000 (42%)</span>
#
#
# <span>Save ₹2,000 (11%)</span>
#
#
# <span>Save ₹5,000 (29%)</span>
#
#
# <span>Save ₹32,000 (39%)</span>
#
#
# ...
